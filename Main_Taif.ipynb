# %% [markdown]
# # Lab : Image Classification using Convolutional Neural Networks
#
# At the end of this laboratory, you would get familiarized with
#
# *   Creating deep networks using Keras
# *   Steps necessary in training a neural network
# *   Prediction and performance analysis using neural networks
#
# ---

# %% [markdown]
# # **In case you use a colaboratory environment**
# By default, Colab notebooks run on CPU.
# You can switch your notebook to run with GPU.
#
# In order to obtain access to the GPU, you need to choose the tab Runtime and then select “Change runtime type” as shown in the following figure:
#
# ![Changing runtime](https://miro.medium.com/max/747/1*euE7nGZ0uJQcgvkpgvkoQg.png)
#
# When a pop-up window appears select GPU. Ensure “Hardware accelerator” is set to GPU.

# %% [markdown]
# # **Working with a new dataset: CIFAR-10**
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. More information about CIFAR-10 can be found [here](https://www.cs.toronto.edu/~kriz/cifar.html).
#
# In Keras, the CIFAR-10 dataset is also preloaded in the form of four Numpy arrays. x_train and y_train contain the training set, while x_test and y_test contain the test data. The images are encoded as Numpy arrays and their corresponding labels ranging from 0 to 9.
#
# Your task is to:
#
# *   Visualize the images in CIFAR-10 dataset. Create a 10 x 10 plot showing 10 random samples from each class.
# *   Convert the labels to one-hot encoded form.
# *   Normalize the images.

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.src.optimizers import SGD
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step

# %%
# Create a figure and axes for plotting
fig, axes = plt.subplots(10, 10, figsize=(10, 10))

# Flatten the axes array for easier indexing
axes = axes.ravel()

# Get the unique classes in CIFAR-10
classes = np.unique(y_train)

# Loop through each class
for i, cls in enumerate(classes):
  # Filter images belonging to the current class
  class_indices = np.where(y_train == cls)[0]

  # Randomly select 10 images from the filtered indices
  random_indices = np.random.choice(class_indices, 10, replace=False)

  # Display each selected image
  for j, idx in enumerate(random_indices):
    axes[i * 10 + j].imshow(x_train[idx])
    axes[i * 10 + j].axis('off')

# Display the plot
plt.show()

# %%
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %%
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

print(x_train.shape)
print(x_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def print_compare(history):
  plt.title('Cross Entropy Loss')
  plt.plot(history.history['loss'], color='blue', label='train')
  plt.show()

  plt.title('Classification Accuracy')
  plt.plot(history.history['accuracy'], color='green', label='train')
  plt.show()

# %% [markdown]
# ## Define the following model (same as the one in tutorial)
#
# For the convolutional front-end, start with a single convolutional layer with a small filter size (3,3) and a modest number of filters (32) followed by a max pooling layer.
#
# Use the input as (32,32,3).
#
# The filter maps can then be flattened to provide features to the classifier.
#
# Use a dense layer with 100 units before the classification layer (which is also a dense layer with softmax activation).

# %%
keras.backend.clear_session()

# %%
model = keras.Sequential(
    [
        keras.layers.Input(shape=(32,32,3)),
        keras.layers.Conv2D(32, (3, 3), activation='relu'),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Flatten(),
        keras.layers.Dense(100, activation="relu"),
        keras.layers.Dense(10, activation="softmax")
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 7200)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 100)                 │         720,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 722,006 (2.75 MB)
#  Trainable params: 722,006 (2.75 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 50 epochs with a batch size of 512.

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=60, batch_size=512, validation_data=(x_test, y_test))
# Out:
# Epoch 1/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8167 - loss: 0.5589 - val_accuracy: 0.6628 - val_loss: 1.0187
# Epoch 2/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8198 - loss: 0.5565 - val_accuracy: 0.6667 - val_loss: 1.0045
# Epoch 3/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8160 - loss: 0.5582 - val_accuracy: 0.6641 - val_loss: 1.0075
# Epoch 4/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8252 - loss: 0.5430 - val_accuracy: 0.6639 - val_loss: 1.0179
# Epoch 5/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8153 - loss: 0.5672 - val_accuracy: 0.6661 - val_loss: 1.0078
# Epoch 6/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8231 - loss: 0.5458 - val_accuracy: 0.6667 - val_loss: 1.0147
# Epoch 7/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8187 - loss: 0.5553 - val_accuracy: 0.6660 - val_loss: 1.0047
# Epoch 8/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8235 - loss: 0.5413 - val_accuracy: 0.6612 - val_loss: 1.0278
# Epoch 9/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8231 - loss: 0.5478 - val_accuracy: 0.6648 - val_loss: 1.0251
# Epoch 10/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8268 - loss: 0.5394 - val_accuracy: 0.6635 - val_loss: 1.0269
# Epoch 11/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8254 - loss: 0.5340 - val_accuracy: 0.6550 - val_loss: 1.0484
# Epoch 12/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8192 - loss: 0.5482 - val_accuracy: 0.6646 - val_loss: 1.0174
# Epoch 13/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8302 - loss: 0.5342 - val_accuracy: 0.6648 - val_loss: 1.0343
# Epoch 14/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8308 - loss: 0.5250 - val_accuracy: 0.6635 - val_loss: 1.0238
# Epoch 15/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8269 - loss: 0.5327 - val_accuracy: 0.6543 - val_loss: 1.0484
# Epoch 16/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8300 - loss: 0.5215 - val_accuracy: 0.6484 - val_loss: 1.0686
# Epoch 17/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8296 - loss: 0.5263 - val_accuracy: 0.6409 - val_loss: 1.0946
# Epoch 18/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8203 - loss: 0.5476 - val_accuracy: 0.6583 - val_loss: 1.0492
# Epoch 19/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8313 - loss: 0.5221 - val_accuracy: 0.6580 - val_loss: 1.0483
# Epoch 20/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8343 - loss: 0.5157 - val_accuracy: 0.6586 - val_loss: 1.0458
# Epoch 21/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8361 - loss: 0.5129 - val_accuracy: 0.6605 - val_loss: 1.0462
# Epoch 22/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8393 - loss: 0.5074 - val_accuracy: 0.6505 - val_loss: 1.0524
# Epoch 23/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8359 - loss: 0.5117 - val_accuracy: 0.6530 - val_loss: 1.0705
# Epoch 24/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8322 - loss: 0.5177 - val_accuracy: 0.6618 - val_loss: 1.0304
# Epoch 25/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8406 - loss: 0.5074 - val_accuracy: 0.6486 - val_loss: 1.1056
# Epoch 26/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8383 - loss: 0.5023 - val_accuracy: 0.6588 - val_loss: 1.0490
# Epoch 27/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8367 - loss: 0.5054 - val_accuracy: 0.6645 - val_loss: 1.0475
# Epoch 28/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8332 - loss: 0.5143 - val_accuracy: 0.6489 - val_loss: 1.0812
# Epoch 29/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8400 - loss: 0.4988 - val_accuracy: 0.6632 - val_loss: 1.0427
# Epoch 30/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8385 - loss: 0.5021 - val_accuracy: 0.6611 - val_loss: 1.0426
# Epoch 31/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8454 - loss: 0.4912 - val_accuracy: 0.6580 - val_loss: 1.0452
# Epoch 32/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8445 - loss: 0.4894 - val_accuracy: 0.6655 - val_loss: 1.0364
# Epoch 33/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8421 - loss: 0.4902 - val_accuracy: 0.6555 - val_loss: 1.0859
# Epoch 34/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8483 - loss: 0.4804 - val_accuracy: 0.6639 - val_loss: 1.0510
# Epoch 35/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8459 - loss: 0.4834 - val_accuracy: 0.6552 - val_loss: 1.0588
# Epoch 36/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8476 - loss: 0.4814 - val_accuracy: 0.6565 - val_loss: 1.0788
# Epoch 37/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8427 - loss: 0.4881 - val_accuracy: 0.6439 - val_loss: 1.0928
# Epoch 38/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8427 - loss: 0.4927 - val_accuracy: 0.6652 - val_loss: 1.0342
# Epoch 39/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8506 - loss: 0.4727 - val_accuracy: 0.6631 - val_loss: 1.0487
# Epoch 40/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8521 - loss: 0.4689 - val_accuracy: 0.6570 - val_loss: 1.0780
# Epoch 41/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8546 - loss: 0.4646 - val_accuracy: 0.6673 - val_loss: 1.0505
# Epoch 42/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8518 - loss: 0.4674 - val_accuracy: 0.6602 - val_loss: 1.0723
# Epoch 43/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8520 - loss: 0.4656 - val_accuracy: 0.6629 - val_loss: 1.0571
# Epoch 44/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8553 - loss: 0.4636 - val_accuracy: 0.6597 - val_loss: 1.0612
# Epoch 45/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8544 - loss: 0.4623 - val_accuracy: 0.6486 - val_loss: 1.1056
# Epoch 46/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8514 - loss: 0.4641 - val_accuracy: 0.6573 - val_loss: 1.0655
# Epoch 47/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8589 - loss: 0.4522 - val_accuracy: 0.6640 - val_loss: 1.0616
# Epoch 48/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8618 - loss: 0.4463 - val_accuracy: 0.6638 - val_loss: 1.0636
# Epoch 49/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8552 - loss: 0.4564 - val_accuracy: 0.6607 - val_loss: 1.0726
# Epoch 50/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8615 - loss: 0.4457 - val_accuracy: 0.6437 - val_loss: 1.1273
# Epoch 51/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8657 - loss: 0.4393 - val_accuracy: 0.6566 - val_loss: 1.0776
# Epoch 52/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8599 - loss: 0.4437 - val_accuracy: 0.6535 - val_loss: 1.0964
# Epoch 53/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8607 - loss: 0.4478 - val_accuracy: 0.6617 - val_loss: 1.0793
# Epoch 54/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8597 - loss: 0.4451 - val_accuracy: 0.6647 - val_loss: 1.0541
# Epoch 55/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8638 - loss: 0.4345 - val_accuracy: 0.6552 - val_loss: 1.0953
# Epoch 56/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8702 - loss: 0.4246 - val_accuracy: 0.6427 - val_loss: 1.1403
# Epoch 57/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8620 - loss: 0.4395 - val_accuracy: 0.6620 - val_loss: 1.0615
# Epoch 58/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8683 - loss: 0.4303 - val_accuracy: 0.6595 - val_loss: 1.0760
# Epoch 59/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8666 - loss: 0.4294 - val_accuracy: 0.6646 - val_loss: 1.0563
# Epoch 60/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8713 - loss: 0.4227 - val_accuracy: 0.6624 - val_loss: 1.0844

# %% [markdown]
# *   Plot the cross entropy loss curve and the accuracy curve

# %%
print_compare(history)

# %% [markdown]
# ## Defining Deeper Architectures: VGG Models
#
# *   Define a deeper model architecture for CIFAR-10 dataset and train the new model for 50 epochs with a batch size of 512. We will use VGG model as the architecture.
#
# Stack two convolutional layers with 32 filters, each of 3 x 3.
#
# Use a max pooling layer and next flatten the output of the previous layer and add a dense layer with 128 units before the classification layer.
#
# For all the layers, use ReLU activation function.
#
# Use same padding for the layers to ensure that the height and width of each layer output matches the input

# %%
keras.backend.clear_session()

# %%
model2 = keras.Sequential(
    [
        keras.layers.Input(shape=(32,32,3)),
        keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'),
        keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Flatten(),
        keras.layers.Dense(128, activation="relu", kernel_initializer='he_uniform'),
        keras.layers.Dense(10, activation="softmax")
    ]
)
model2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       1,048,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,060,138 (4.04 MB)
#  Trainable params: 1,060,138 (4.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 50 epochs with a batch size of 512.

# %%
model2.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history2 = model2.fit(x_train, y_train, epochs=50, batch_size=512, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.1806 - loss: 2.2097 - val_accuracy: 0.2973 - val_loss: 1.9821
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.3004 - loss: 1.9765 - val_accuracy: 0.3520 - val_loss: 1.8617
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.3606 - loss: 1.8403 - val_accuracy: 0.3355 - val_loss: 1.9007
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.3972 - loss: 1.7435 - val_accuracy: 0.3968 - val_loss: 1.6929
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.4151 - loss: 1.6728 - val_accuracy: 0.4120 - val_loss: 1.6566
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4338 - loss: 1.6177 - val_accuracy: 0.4226 - val_loss: 1.6124
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4470 - loss: 1.5701 - val_accuracy: 0.4507 - val_loss: 1.5635
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.4618 - loss: 1.5240 - val_accuracy: 0.4727 - val_loss: 1.4924
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4786 - loss: 1.4887 - val_accuracy: 0.4672 - val_loss: 1.4925
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4911 - loss: 1.4474 - val_accuracy: 0.4830 - val_loss: 1.4723
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4967 - loss: 1.4296 - val_accuracy: 0.4896 - val_loss: 1.4635
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5103 - loss: 1.4038 - val_accuracy: 0.5102 - val_loss: 1.3790
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5285 - loss: 1.3524 - val_accuracy: 0.4912 - val_loss: 1.4514
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5287 - loss: 1.3425 - val_accuracy: 0.5257 - val_loss: 1.3334
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5378 - loss: 1.3194 - val_accuracy: 0.5332 - val_loss: 1.3160
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5471 - loss: 1.2983 - val_accuracy: 0.5412 - val_loss: 1.2913
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5567 - loss: 1.2682 - val_accuracy: 0.5430 - val_loss: 1.2811
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5626 - loss: 1.2477 - val_accuracy: 0.5316 - val_loss: 1.3343
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5724 - loss: 1.2295 - val_accuracy: 0.5621 - val_loss: 1.2504
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5802 - loss: 1.1993 - val_accuracy: 0.5516 - val_loss: 1.2603
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5833 - loss: 1.1939 - val_accuracy: 0.5703 - val_loss: 1.2231
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5874 - loss: 1.1807 - val_accuracy: 0.5595 - val_loss: 1.2377
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5941 - loss: 1.1589 - val_accuracy: 0.5818 - val_loss: 1.1910
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6008 - loss: 1.1534 - val_accuracy: 0.5624 - val_loss: 1.2476
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5996 - loss: 1.1533 - val_accuracy: 0.5758 - val_loss: 1.2088
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6077 - loss: 1.1284 - val_accuracy: 0.5696 - val_loss: 1.1995
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6138 - loss: 1.1096 - val_accuracy: 0.5836 - val_loss: 1.1749
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6175 - loss: 1.0933 - val_accuracy: 0.5901 - val_loss: 1.1511
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6198 - loss: 1.0854 - val_accuracy: 0.5963 - val_loss: 1.1521
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6251 - loss: 1.0665 - val_accuracy: 0.5879 - val_loss: 1.1551
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6288 - loss: 1.0645 - val_accuracy: 0.6074 - val_loss: 1.1122
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6368 - loss: 1.0482 - val_accuracy: 0.5959 - val_loss: 1.1426
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6368 - loss: 1.0349 - val_accuracy: 0.5993 - val_loss: 1.1312
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6438 - loss: 1.0219 - val_accuracy: 0.6019 - val_loss: 1.1290
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6507 - loss: 1.0119 - val_accuracy: 0.6187 - val_loss: 1.0878
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6527 - loss: 1.0067 - val_accuracy: 0.6106 - val_loss: 1.1102
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6488 - loss: 1.0114 - val_accuracy: 0.6061 - val_loss: 1.1049
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6570 - loss: 0.9934 - val_accuracy: 0.6215 - val_loss: 1.0766
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6604 - loss: 0.9719 - val_accuracy: 0.6182 - val_loss: 1.0924
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6647 - loss: 0.9698 - val_accuracy: 0.6145 - val_loss: 1.1009
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6715 - loss: 0.9602 - val_accuracy: 0.5814 - val_loss: 1.1930
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6749 - loss: 0.9443 - val_accuracy: 0.6181 - val_loss: 1.0917
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6703 - loss: 0.9504 - val_accuracy: 0.6235 - val_loss: 1.0730
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6776 - loss: 0.9337 - val_accuracy: 0.6088 - val_loss: 1.1092
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6757 - loss: 0.9327 - val_accuracy: 0.6397 - val_loss: 1.0397
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6886 - loss: 0.9027 - val_accuracy: 0.6139 - val_loss: 1.1343
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6878 - loss: 0.9129 - val_accuracy: 0.6272 - val_loss: 1.0570
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6845 - loss: 0.9120 - val_accuracy: 0.6163 - val_loss: 1.0850
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6909 - loss: 0.8901 - val_accuracy: 0.6388 - val_loss: 1.0303
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6964 - loss: 0.8807 - val_accuracy: 0.6272 - val_loss: 1.0784

# %%
_, test_acc = model2.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6321 - loss: 1.0660
# Test accuracy: 0.6272000074386597

# %% [markdown]
# *   Compare the performance of both the models by plotting the loss and accuracy curves of both the training steps. Does the deeper model perform better? Comment on the observation.

# %%
print_compare(history2)

# %% [markdown]
# **Comment on the observation**
#
# it is a abit slower but butter result...

# %% [markdown]
# *   Use predict function to predict the output for the test split
# *   Plot the confusion matrix for the new model and comment on the class confusions.

# %%
predictions = model2.predict(x_test)
predictions = np.argmax(predictions, axis=1)
gt = np.argmax(y_test, axis=1)
cm = confusion_matrix(gt, predictions)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# **Comment here :**
#
# There is significant room for improvement. While the true positives outnumbered the false positives, certain misclassifications stand out. For instance, in class 0, there were 172 false positives misclassified as class 8. Similarly, in class 2, there were 200 false positives misclassified as class 9

# %% [markdown]
# *    Print the test accuracy for the trained model.

# %%
test_loss, test_acc = model2.evaluate(x_test, y_test)  # Use y_test directly
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6321 - loss: 1.0660
# Test loss: 1.0783840417861938
# Test accuracy: 0.6272000074386597

# %% [markdown]
# ## Define the complete VGG architecture.
#
# Stack two convolutional layers with 64 filters, each of 3 x 3 followed by max pooling layer.
#
# Stack two more convolutional layers with 128 filters, each of 3 x 3, followed by max pooling, followed by two more convolutional layers with 256 filters, each of 3 x 3, followed by max pooling.
#
# Flatten the output of the previous layer and add a dense layer with 128 units before the classification layer.
#
# For all the layers, use ReLU activation function.
#
# Use same padding for the layers to ensure that the height and width of each layer output matches the input
#
# *   Change the size of input to 64 x 64.

# %%
# Resize the CIFAR-10 images from 32x32 to 64x64
x_train_resized = tf.image.resize(x_train, (64, 64))
x_test_resized = tf.image.resize(x_test, (64, 64))

print(x_train_resized.shape)
print(x_test_resized.shape)
# Out:
# (50000, 64, 64, 3)
# (10000, 64, 64, 3)

# %%
keras.backend.clear_session()

# %%
model3 = keras.Sequential(
    [
        keras.layers.Input(shape=(64, 64, 3)),
        keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Flatten(),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dense(10, activation="softmax")
    ]
)
model3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 64, 64, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 32, 32, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 16, 16, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 16, 16, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 16384)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       2,097,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,243,978 (12.37 MB)
#  Trainable params: 3,243,978 (12.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 10 epochs with a batch size of 512.
# *   Predict the output for the test split and plot the confusion matrix for the new model and comment on the class confusions.

# %%
model3.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model3.fit(x_train_resized, y_train, epochs=10, batch_size=512, validation_data=(x_test_resized, y_test))
# Out:
# Epoch 1/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 125s 874ms/step - accuracy: 0.1159 - loss: 2.3015 - val_accuracy: 0.1603 - val_loss: 2.2982
# Epoch 2/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 386ms/step - accuracy: 0.1617 - loss: 2.2967 - val_accuracy: 0.1546 - val_loss: 2.2896
# Epoch 3/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 40s 380ms/step - accuracy: 0.1622 - loss: 2.2844 - val_accuracy: 0.2043 - val_loss: 2.2511
# Epoch 4/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 378ms/step - accuracy: 0.2080 - loss: 2.2156 - val_accuracy: 0.2005 - val_loss: 2.1159
# Epoch 5/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 381ms/step - accuracy: 0.2485 - loss: 2.0897 - val_accuracy: 0.3198 - val_loss: 1.9594
# Epoch 6/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 380ms/step - accuracy: 0.2959 - loss: 1.9778 - val_accuracy: 0.3328 - val_loss: 1.8883
# Epoch 7/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 381ms/step - accuracy: 0.3151 - loss: 1.9205 - val_accuracy: 0.3080 - val_loss: 1.9448
# Epoch 8/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 37s 382ms/step - accuracy: 0.3373 - loss: 1.8600 - val_accuracy: 0.3569 - val_loss: 1.8147
# Epoch 9/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 383ms/step - accuracy: 0.3566 - loss: 1.8158 - val_accuracy: 0.3902 - val_loss: 1.7293
# Epoch 10/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 388ms/step - accuracy: 0.3765 - loss: 1.7584 - val_accuracy: 0.3799 - val_loss: 1.7648

# %%
print_compare(history)

# %%
test_loss, test_acc = model2.evaluate(x_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6321 - loss: 1.0660
# Test loss: 1.0783840417861938
# Test accuracy: 0.6272000074386597

# %%
predictions = model3.predict(x_test_resized)
predictions = np.argmax(predictions, axis=1)
gt = np.argmax(y_test, axis=1)
cm = confusion_matrix(gt, predictions)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %%
keras.backend.clear_session()
model2 = keras.Sequential(
    [
        keras.layers.Input(shape=(32,32,3)),
        keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'),
        keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Flatten(),
        keras.layers.Dense(128, activation="relu", kernel_initializer='he_uniform'),
        keras.layers.Dense(10, activation="softmax")
    ]
)
model2.summary()

optimizer = SGD(learning_rate=0.01, momentum=0.9)
model2.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

history2 = model2.fit(x_train, y_train, epochs=100, batch_size=512, validation_data=(x_test, y_test))

_, test_acc = model2.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)

print_compare(history2)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       1,048,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,060,138 (4.04 MB)
#  Trainable params: 1,060,138 (4.04 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.2491 - loss: 2.0645 - val_accuracy: 0.4010 - val_loss: 1.6889
# Epoch 2/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4415 - loss: 1.5835 - val_accuracy: 0.5079 - val_loss: 1.3852
# Epoch 3/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5228 - loss: 1.3553 - val_accuracy: 0.5530 - val_loss: 1.2531
# Epoch 4/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5799 - loss: 1.1968 - val_accuracy: 0.5813 - val_loss: 1.1768
# Epoch 5/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6238 - loss: 1.0854 - val_accuracy: 0.6088 - val_loss: 1.1222
# Epoch 6/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6459 - loss: 1.0164 - val_accuracy: 0.6232 - val_loss: 1.0656
# Epoch 7/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6736 - loss: 0.9459 - val_accuracy: 0.6351 - val_loss: 1.0390
# Epoch 8/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.6958 - loss: 0.8953 - val_accuracy: 0.6506 - val_loss: 1.0017
# Epoch 9/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.7101 - loss: 0.8379 - val_accuracy: 0.6674 - val_loss: 0.9690
# Epoch 10/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7312 - loss: 0.7788 - val_accuracy: 0.6594 - val_loss: 0.9940
# Epoch 11/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7430 - loss: 0.7457 - val_accuracy: 0.6719 - val_loss: 0.9642
# Epoch 12/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7692 - loss: 0.6865 - val_accuracy: 0.6652 - val_loss: 0.9738
# Epoch 13/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7819 - loss: 0.6435 - val_accuracy: 0.6723 - val_loss: 0.9690
# Epoch 14/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7998 - loss: 0.5919 - val_accuracy: 0.6725 - val_loss: 0.9943
# Epoch 15/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8130 - loss: 0.5606 - val_accuracy: 0.6734 - val_loss: 0.9922
# Epoch 16/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8255 - loss: 0.5188 - val_accuracy: 0.6740 - val_loss: 1.0004
# Epoch 17/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8401 - loss: 0.4778 - val_accuracy: 0.6705 - val_loss: 1.0504
# Epoch 18/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8625 - loss: 0.4233 - val_accuracy: 0.6751 - val_loss: 1.0414
# Epoch 19/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8759 - loss: 0.3771 - val_accuracy: 0.6671 - val_loss: 1.1095
# Epoch 20/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8870 - loss: 0.3451 - val_accuracy: 0.6578 - val_loss: 1.1533
# Epoch 21/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9080 - loss: 0.2937 - val_accuracy: 0.6599 - val_loss: 1.1931
# Epoch 22/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9190 - loss: 0.2641 - val_accuracy: 0.6737 - val_loss: 1.2076
# Epoch 23/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9350 - loss: 0.2202 - val_accuracy: 0.6577 - val_loss: 1.3064
# Epoch 24/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9436 - loss: 0.1946 - val_accuracy: 0.6674 - val_loss: 1.3400
# Epoch 25/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9525 - loss: 0.1678 - val_accuracy: 0.6628 - val_loss: 1.4156
# Epoch 26/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9637 - loss: 0.1368 - val_accuracy: 0.6622 - val_loss: 1.4839
# Epoch 27/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9727 - loss: 0.1118 - val_accuracy: 0.6617 - val_loss: 1.5282
# Epoch 28/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9821 - loss: 0.0838 - val_accuracy: 0.6603 - val_loss: 1.6205
# Epoch 29/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9871 - loss: 0.0682 - val_accuracy: 0.6584 - val_loss: 1.7210
# Epoch 30/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9921 - loss: 0.0517 - val_accuracy: 0.6620 - val_loss: 1.7808
# Epoch 31/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9946 - loss: 0.0421 - val_accuracy: 0.6632 - val_loss: 1.8381
# Epoch 32/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9966 - loss: 0.0332 - val_accuracy: 0.6636 - val_loss: 1.9034
# Epoch 33/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9980 - loss: 0.0259 - val_accuracy: 0.6623 - val_loss: 1.9486
# Epoch 34/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9993 - loss: 0.0175 - val_accuracy: 0.6632 - val_loss: 1.9970
# Epoch 35/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9996 - loss: 0.0127 - val_accuracy: 0.6623 - val_loss: 2.0581
# Epoch 36/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9995 - loss: 0.0116 - val_accuracy: 0.6629 - val_loss: 2.0912
# Epoch 37/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9998 - loss: 0.0089 - val_accuracy: 0.6606 - val_loss: 2.1316
# Epoch 38/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9999 - loss: 0.0078 - val_accuracy: 0.6638 - val_loss: 2.1816
# Epoch 39/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9998 - loss: 0.0072 - val_accuracy: 0.6625 - val_loss: 2.2131
# Epoch 40/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9999 - loss: 0.0064 - val_accuracy: 0.6635 - val_loss: 2.2358
# Epoch 41/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9999 - loss: 0.0054 - val_accuracy: 0.6606 - val_loss: 2.2710
# Epoch 42/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9999 - loss: 0.0049 - val_accuracy: 0.6653 - val_loss: 2.2939
# Epoch 43/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9999 - loss: 0.0046 - val_accuracy: 0.6619 - val_loss: 2.3156
# Epoch 44/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.6625 - val_loss: 2.3440
# Epoch 45/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.6610 - val_loss: 2.3665
# Epoch 46/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.6627 - val_loss: 2.3828
# Epoch 47/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.6589 - val_loss: 2.4062
# Epoch 48/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.6608 - val_loss: 2.4254
# Epoch 49/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9999 - loss: 0.0030 - val_accuracy: 0.6642 - val_loss: 2.4400
# Epoch 50/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.6623 - val_loss: 2.4582
# Epoch 51/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.6624 - val_loss: 2.4813
# Epoch 52/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.6630 - val_loss: 2.4937
# Epoch 53/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.6621 - val_loss: 2.5088
# Epoch 54/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.6633 - val_loss: 2.5230
# Epoch 55/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.6635 - val_loss: 2.5402
# Epoch 56/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.6634 - val_loss: 2.5517
# Epoch 57/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.6615 - val_loss: 2.5651
# Epoch 58/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6629 - val_loss: 2.5805
# Epoch 59/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6633 - val_loss: 2.5911
# Epoch 60/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6621 - val_loss: 2.6011
# Epoch 61/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6627 - val_loss: 2.6141
# Epoch 62/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6626 - val_loss: 2.6244
# Epoch 63/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6631 - val_loss: 2.6365
# Epoch 64/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6619 - val_loss: 2.6503
# Epoch 65/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6626 - val_loss: 2.6579
# Epoch 66/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6614 - val_loss: 2.6709
# Epoch 67/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6621 - val_loss: 2.6794
# Epoch 68/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6621 - val_loss: 2.6890
# Epoch 69/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6631 - val_loss: 2.6979
# Epoch 70/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6615 - val_loss: 2.7083
# Epoch 71/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6632 - val_loss: 2.7167
# Epoch 72/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6641 - val_loss: 2.7257
# Epoch 73/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6619 - val_loss: 2.7323
# Epoch 74/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6635 - val_loss: 2.7421
# Epoch 75/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6606 - val_loss: 2.7512
# Epoch 76/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.6618 - val_loss: 2.7575
# Epoch 77/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.6621 - val_loss: 2.7658
# Epoch 78/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 9.8068e-04 - val_accuracy: 0.6615 - val_loss: 2.7731
# Epoch 79/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 1.0000 - loss: 9.6444e-04 - val_accuracy: 0.6616 - val_loss: 2.7850
# Epoch 80/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 9.3140e-04 - val_accuracy: 0.6621 - val_loss: 2.7918
# Epoch 81/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 8.9757e-04 - val_accuracy: 0.6620 - val_loss: 2.8004
# Epoch 82/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 8.8673e-04 - val_accuracy: 0.6620 - val_loss: 2.8036
# Epoch 83/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 8.5640e-04 - val_accuracy: 0.6609 - val_loss: 2.8139
# Epoch 84/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 1.0000 - loss: 8.5937e-04 - val_accuracy: 0.6616 - val_loss: 2.8209
# Epoch 85/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 1.0000 - loss: 8.2328e-04 - val_accuracy: 0.6628 - val_loss: 2.8259
# Epoch 86/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 8.0207e-04 - val_accuracy: 0.6615 - val_loss: 2.8339
# Epoch 87/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 8.0099e-04 - val_accuracy: 0.6626 - val_loss: 2.8394
# Epoch 88/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 7.9891e-04 - val_accuracy: 0.6626 - val_loss: 2.8451
# Epoch 89/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 7.7209e-04 - val_accuracy: 0.6615 - val_loss: 2.8536
# Epoch 90/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 1.0000 - loss: 7.5586e-04 - val_accuracy: 0.6625 - val_loss: 2.8606
# Epoch 91/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 7.4129e-04 - val_accuracy: 0.6616 - val_loss: 2.8656
# Epoch 92/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 7.2039e-04 - val_accuracy: 0.6618 - val_loss: 2.8721
# Epoch 93/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 7.0854e-04 - val_accuracy: 0.6624 - val_loss: 2.8778
# Epoch 94/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 7.0696e-04 - val_accuracy: 0.6620 - val_loss: 2.8839
# Epoch 95/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 6.9069e-04 - val_accuracy: 0.6625 - val_loss: 2.8906
# Epoch 96/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 1.0000 - loss: 6.7080e-04 - val_accuracy: 0.6619 - val_loss: 2.8953
# Epoch 97/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 6.7144e-04 - val_accuracy: 0.6615 - val_loss: 2.9030
# Epoch 98/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 6.3517e-04 - val_accuracy: 0.6620 - val_loss: 2.9077
# Epoch 99/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 6.2972e-04 - val_accuracy: 0.6626 - val_loss: 2.9124
# Epoch 100/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 1.0000 - loss: 6.2718e-04 - val_accuracy: 0.6618 - val_loss: 2.9180
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6605 - loss: 2.8944
# Test accuracy: 0.6618000268936157

# %% [markdown]
# The model will improve my time, I think with more epoches the result can be not too bad. The overfitting has improved, the validation and the train values are close each other.

# %% [markdown]
# # Understanding deep networks
#
# *   What is the use of activation functions in network? Why is it needed?
# *   We have used softmax activation function in the exercise. There are other activation functions available too. What is the difference between sigmoid activation and softmax activation?
# *   What is the difference between categorical crossentropy and binary crossentropy loss?

# %% [markdown]
# **Write the answers below :**
#
# 1 - Purpose of Activation Functions: Activation functions add non-linearity to neural networks, allowing them to model and learn complex patterns present in the input data, similar to natural phenomena.
#
# _
#
# 2 - Difference Between Sigmoid and Softmax: Sigmoid functions are ideal for binary classification tasks, whereas softmax is better suited for multi-class classification as it provides a probability distribution across multiple classes.
#
# _
#
# 3 - Difference Between Categorical Crossentropy and Binary Crossentropy: Categorical crossentropy is designed for multi-class classification problems, while binary crossentropy is tailored for binary classification tasks.
